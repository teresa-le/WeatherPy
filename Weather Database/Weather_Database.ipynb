# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = [] 

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
   
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 755

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        lat = city_weather["coord"]["lat"]
        lng = city_weather["coord"]["lon"]
        max_temp = city_weather["main"]["temp_max"]
        humidity = city_weather["main"]["humidity"]
        clouds = city_weather["clouds"]["all"]
        wind = city_weather["wind"]["speed"]  
        country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"] 
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": lat,
                          "Lng": lng,
                          "Max Temp": max_temp,
                          "Humidity": humidity,
                          "Cloudiness": clouds,
                          "Wind Speed": wind,
                          "Country": country,
                          "Current Description": weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | hilo
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | santo domingo
# Processing Record 5 of Set 1 | saldanha
# Processing Record 6 of Set 1 | niteroi
# Processing Record 7 of Set 1 | guane
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | hobart
# Processing Record 10 of Set 1 | kodiak
# Processing Record 11 of Set 1 | cascais
# Processing Record 12 of Set 1 | butaritari
# Processing Record 13 of Set 1 | torbay
# Processing Record 14 of Set 1 | bredasdorp
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 17 of Set 1 | adrar
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | sao joao da barra
# Processing Record 20 of Set 1 | progreso
# Processing Record 21 of Set 1 | san rafael
# Processing Record 22 of Set 1 | hambantota
# Processing Record 23 of Set 1 | pevek
# Processing Record 24 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 1 | ust-nera
# Processing Record 26 of Set 1 | mayfield
# Processing Record 27 of Set 1 | farah
# Processing Record 28 of Set 1 | ribeira grande
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | kruisfontein
# Processing Record 31 of Set 1 | mae hong son
# Processing Record 32 of Set 1 | matara
# Processing Record 33 of Set 1 | nhulunbuy
# Processing Record 34 of Set 1 | thompson
# Processing Record 35 of Set 1 | qitaihe
# Processing Record 36 of Set 1 | wageningen
# Processing Record 37 of Set 1 | tilichiki
# Processing Record 38 of Set 1 | hasaki
# Processing Record 39 of Set 1 | menongue
# Processing Record 40 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 1 | kapaa
# Processing Record 42 of Set 1 | new norfolk
# Processing Record 43 of Set 1 | talnakh
# Processing Record 44 of Set 1 | carnarvon
# Processing Record 45 of Set 1 | bambous virieux
# Processing Record 46 of Set 1 | cidreira
# Processing Record 47 of Set 1 | bethel
# Processing Record 48 of Set 1 | kurilsk
# Processing Record 49 of Set 1 | lompoc
# Processing Record 50 of Set 1 | flin flon
# Processing Record 1 of Set 2 | nelson bay
# Processing Record 2 of Set 2 | punta arenas
# Processing Record 3 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 2 | castro
# Processing Record 5 of Set 2 | saint george
# Processing Record 6 of Set 2 | port elizabeth
# Processing Record 7 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 2 | srednekolymsk
# Processing Record 9 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 2 | chiredzi
# Processing Record 11 of Set 2 | hit
# Processing Record 12 of Set 2 | lebu
# Processing Record 13 of Set 2 | vila franca do campo
# Processing Record 14 of Set 2 | pitimbu
# Processing Record 15 of Set 2 | santa maria
# Processing Record 16 of Set 2 | hermanus
# Processing Record 17 of Set 2 | port alfred
# Processing Record 18 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 19 of Set 2 | sinnamary
# Processing Record 20 of Set 2 | yishui
# Processing Record 21 of Set 2 | yellowknife
# Processing Record 22 of Set 2 | bluff
# Processing Record 23 of Set 2 | mar del plata
# Processing Record 24 of Set 2 | saint-philippe
# Processing Record 25 of Set 2 | kahului
# Processing Record 26 of Set 2 | husavik
# Processing Record 27 of Set 2 | coro
# Processing Record 28 of Set 2 | alice springs
# Processing Record 29 of Set 2 | nicoya
# Processing Record 30 of Set 2 | kyshtovka
# Processing Record 31 of Set 2 | ushuaia
# Processing Record 32 of Set 2 | coquimbo
# Processing Record 33 of Set 2 | namibe
# Processing Record 34 of Set 2 | batagay-alyta
# Processing Record 35 of Set 2 | souillac
# Processing Record 36 of Set 2 | makakilo city
# Processing Record 37 of Set 2 | sataua
# City not found. Skipping...
# Processing Record 38 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 39 of Set 2 | de-kastri
# Processing Record 40 of Set 2 | tome-acu
# City not found. Skipping...
# Processing Record 41 of Set 2 | poum
# Processing Record 42 of Set 2 | puerto ayora
# Processing Record 43 of Set 2 | upernavik
# Processing Record 44 of Set 2 | khash
# Processing Record 45 of Set 2 | ponta do sol
# Processing Record 46 of Set 2 | codrington
# Processing Record 47 of Set 2 | victoria
# Processing Record 48 of Set 2 | lata
# Processing Record 49 of Set 2 | georgetown
# Processing Record 50 of Set 2 | poya
# Processing Record 1 of Set 3 | touros
# Processing Record 2 of Set 3 | katsuura
# Processing Record 3 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 3 | quatre cocos
# Processing Record 5 of Set 3 | hukuntsi
# Processing Record 6 of Set 3 | ahipara
# Processing Record 7 of Set 3 | jalu
# Processing Record 8 of Set 3 | tuktoyaktuk
# Processing Record 9 of Set 3 | avarua
# Processing Record 10 of Set 3 | itarema
# Processing Record 11 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 3 | korla
# Processing Record 13 of Set 3 | cigand
# Processing Record 14 of Set 3 | roebourne
# Processing Record 15 of Set 3 | pinotepa de don luis
# Processing Record 16 of Set 3 | hailey
# Processing Record 17 of Set 3 | iqaluit
# Processing Record 18 of Set 3 | haines junction
# Processing Record 19 of Set 3 | praia da vitoria
# Processing Record 20 of Set 3 | qaanaaq
# Processing Record 21 of Set 3 | kavieng
# Processing Record 22 of Set 3 | bairnsdale
# Processing Record 23 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 3 | vaini
# Processing Record 25 of Set 3 | abalak
# Processing Record 26 of Set 3 | mahudha
# Processing Record 27 of Set 3 | gilgit
# Processing Record 28 of Set 3 | bengkulu
# Processing Record 29 of Set 3 | chumikan
# Processing Record 30 of Set 3 | mehamn
# Processing Record 31 of Set 3 | faanui
# Processing Record 32 of Set 3 | bolshiye uki
# City not found. Skipping...
# Processing Record 33 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 3 | asfi
# Processing Record 35 of Set 3 | eureka
# Processing Record 36 of Set 3 | port lincoln
# Processing Record 37 of Set 3 | karoi
# Processing Record 38 of Set 3 | cape town
# Processing Record 39 of Set 3 | labuhan
# Processing Record 40 of Set 3 | barrow
# Processing Record 41 of Set 3 | carutapera
# Processing Record 42 of Set 3 | atuona
# Processing Record 43 of Set 3 | whittlesea
# Processing Record 44 of Set 3 | fortuna
# Processing Record 45 of Set 3 | stromness
# Processing Record 46 of Set 3 | airai
# Processing Record 47 of Set 3 | belyy yar
# Processing Record 48 of Set 3 | vitimskiy
# City not found. Skipping...
# Processing Record 49 of Set 3 | brigantine
# Processing Record 50 of Set 3 | pierre
# Processing Record 1 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 4 | puerto penasco
# Processing Record 3 of Set 4 | nishihara
# Processing Record 4 of Set 4 | yomitan
# City not found. Skipping...
# Processing Record 5 of Set 4 | pundaguitan
# Processing Record 6 of Set 4 | guerrero negro
# Processing Record 7 of Set 4 | lalomanu
# City not found. Skipping...
# Processing Record 8 of Set 4 | qui nhon
# Processing Record 9 of Set 4 | alekseyevsk
# Processing Record 10 of Set 4 | saskylakh
# Processing Record 11 of Set 4 | dikson
# Processing Record 12 of Set 4 | severo-kurilsk
# Processing Record 13 of Set 4 | uruacu
# Processing Record 14 of Set 4 | hailar
# Processing Record 15 of Set 4 | tasiilaq
# Processing Record 16 of Set 4 | novoagansk
# Processing Record 17 of Set 4 | buqayq
# City not found. Skipping...
# Processing Record 18 of Set 4 | murgab
# Processing Record 19 of Set 4 | arraial do cabo
# Processing Record 20 of Set 4 | litovko
# Processing Record 21 of Set 4 | port pirie
# Processing Record 22 of Set 4 | viedma
# Processing Record 23 of Set 4 | ancud
# Processing Record 24 of Set 4 | mahibadhoo
# Processing Record 25 of Set 4 | nanortalik
# Processing Record 26 of Set 4 | east london
# Processing Record 27 of Set 4 | marrakesh
# Processing Record 28 of Set 4 | mahebourg
# Processing Record 29 of Set 4 | srivardhan
# Processing Record 30 of Set 4 | artyk
# City not found. Skipping...
# Processing Record 31 of Set 4 | khandyga
# Processing Record 32 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 33 of Set 4 | provideniya
# Processing Record 34 of Set 4 | ust-tsilma
# Processing Record 35 of Set 4 | sokolo
# Processing Record 36 of Set 4 | olkhovka
# Processing Record 37 of Set 4 | chincholi
# Processing Record 38 of Set 4 | goderich
# Processing Record 39 of Set 4 | miandrivazo
# Processing Record 40 of Set 4 | kamaishi
# Processing Record 41 of Set 4 | sorong
# Processing Record 42 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 4 | beloha
# Processing Record 44 of Set 4 | te anau
# Processing Record 45 of Set 4 | chuy
# Processing Record 46 of Set 4 | homer
# Processing Record 47 of Set 4 | huainan
# Processing Record 48 of Set 4 | queanbeyan
# Processing Record 49 of Set 4 | chicama
# Processing Record 50 of Set 4 | thies
# Processing Record 1 of Set 5 | dingle
# Processing Record 2 of Set 5 | karauzyak
# City not found. Skipping...
# Processing Record 3 of Set 5 | hithadhoo
# Processing Record 4 of Set 5 | ksenyevka
# City not found. Skipping...
# Processing Record 5 of Set 5 | la libertad
# Processing Record 6 of Set 5 | hofn
# Processing Record 7 of Set 5 | palembang
# Processing Record 8 of Set 5 | patacamaya
# Processing Record 9 of Set 5 | chokurdakh
# Processing Record 10 of Set 5 | sao filipe
# Processing Record 11 of Set 5 | anito
# Processing Record 12 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 5 | ferrol
# Processing Record 14 of Set 5 | sungaipenuh
# Processing Record 15 of Set 5 | faya
# Processing Record 16 of Set 5 | bathsheba
# Processing Record 17 of Set 5 | leningradskiy
# Processing Record 18 of Set 5 | khudumelapye
# Processing Record 19 of Set 5 | lorengau
# Processing Record 20 of Set 5 | maicao
# Processing Record 21 of Set 5 | pedernales
# Processing Record 22 of Set 5 | palu
# Processing Record 23 of Set 5 | alofi
# Processing Record 24 of Set 5 | vila velha
# Processing Record 25 of Set 5 | black river
# Processing Record 26 of Set 5 | tiksi
# Processing Record 27 of Set 5 | romanovskaya
# Processing Record 28 of Set 5 | amahai
# Processing Record 29 of Set 5 | lusambo
# Processing Record 30 of Set 5 | strelka
# Processing Record 31 of Set 5 | kawana waters
# City not found. Skipping...
# Processing Record 32 of Set 5 | aklavik
# Processing Record 33 of Set 5 | meulaboh
# Processing Record 34 of Set 5 | dera din panah
# City not found. Skipping...
# Processing Record 35 of Set 5 | elizabeth city
# Processing Record 36 of Set 5 | halifax
# Processing Record 37 of Set 5 | bor
# Processing Record 38 of Set 5 | esperance
# Processing Record 39 of Set 5 | agirish
# Processing Record 40 of Set 5 | mudgee
# Processing Record 41 of Set 5 | jieshi
# Processing Record 42 of Set 5 | labrea
# Processing Record 43 of Set 5 | nabire
# Processing Record 44 of Set 5 | shimoda
# Processing Record 45 of Set 5 | nikolskoye
# Processing Record 46 of Set 5 | sagua de tanamo
# Processing Record 47 of Set 5 | olinda
# Processing Record 48 of Set 5 | foumban
# Processing Record 49 of Set 5 | barcelona
# Processing Record 50 of Set 5 | ziway
# Processing Record 1 of Set 6 | ada
# Processing Record 2 of Set 6 | xining
# Processing Record 3 of Set 6 | aykhal
# Processing Record 4 of Set 6 | yulara
# Processing Record 5 of Set 6 | riyadh
# Processing Record 6 of Set 6 | ponta delgada
# Processing Record 7 of Set 6 | aquiraz
# Processing Record 8 of Set 6 | lander
# Processing Record 9 of Set 6 | isangel
# Processing Record 10 of Set 6 | boma
# Processing Record 11 of Set 6 | kiama
# Processing Record 12 of Set 6 | pompeu
# Processing Record 13 of Set 6 | sorland
# Processing Record 14 of Set 6 | huangchuan
# Processing Record 15 of Set 6 | sechura
# Processing Record 16 of Set 6 | ayorou
# Processing Record 17 of Set 6 | piacabucu
# Processing Record 18 of Set 6 | guiset
# City not found. Skipping...
# Processing Record 19 of Set 6 | samfya
# Processing Record 20 of Set 6 | padang
# Processing Record 21 of Set 6 | ust-kuyga
# Processing Record 22 of Set 6 | pisco
# Processing Record 23 of Set 6 | kasongo-lunda
# Processing Record 24 of Set 6 | deputatskiy
# Processing Record 25 of Set 6 | bhag
# Processing Record 26 of Set 6 | laguna
# Processing Record 27 of Set 6 | birao
# Processing Record 28 of Set 6 | salvador
# Processing Record 29 of Set 6 | rancho palos verdes
# Processing Record 30 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 6 | horsham
# Processing Record 32 of Set 6 | strezhevoy
# Processing Record 33 of Set 6 | bonavista
# Processing Record 34 of Set 6 | bartlesville
# Processing Record 35 of Set 6 | sanchor
# Processing Record 36 of Set 6 | cayenne
# Processing Record 37 of Set 6 | sitka
# Processing Record 38 of Set 6 | conde
# Processing Record 39 of Set 6 | san angelo
# Processing Record 40 of Set 6 | tazovskiy
# Processing Record 41 of Set 6 | vanimo
# Processing Record 42 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 43 of Set 6 | nur
# Processing Record 44 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 45 of Set 6 | ballina
# Processing Record 46 of Set 6 | zolotinka
# City not found. Skipping...
# Processing Record 47 of Set 6 | la ronge
# Processing Record 48 of Set 6 | puerto el triunfo
# Processing Record 49 of Set 6 | yerbogachen
# Processing Record 50 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 1 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 7 | cap malheureux
# Processing Record 3 of Set 7 | mattru
# Processing Record 4 of Set 7 | cabo san lucas
# Processing Record 5 of Set 7 | svetlaya
# Processing Record 6 of Set 7 | diego de almagro
# Processing Record 7 of Set 7 | kangalassy
# Processing Record 8 of Set 7 | mount isa
# Processing Record 9 of Set 7 | port hedland
# Processing Record 10 of Set 7 | kichera
# Processing Record 11 of Set 7 | saint anthony
# Processing Record 12 of Set 7 | niamey
# Processing Record 13 of Set 7 | eirunepe
# Processing Record 14 of Set 7 | verkhnetulomskiy
# Processing Record 15 of Set 7 | nome
# Processing Record 16 of Set 7 | longyearbyen
# Processing Record 17 of Set 7 | qandala
# Processing Record 18 of Set 7 | rocha
# Processing Record 19 of Set 7 | fukue
# Processing Record 20 of Set 7 | sharan
# Processing Record 21 of Set 7 | tuatapere
# Processing Record 22 of Set 7 | umm kaddadah
# Processing Record 23 of Set 7 | coahuayana
# Processing Record 24 of Set 7 | watertown
# Processing Record 25 of Set 7 | kaitangata
# Processing Record 26 of Set 7 | orange cove
# Processing Record 27 of Set 7 | ilulissat
# Processing Record 28 of Set 7 | sabang
# Processing Record 29 of Set 7 | livingstonia
# Processing Record 30 of Set 7 | dakar
# Processing Record 31 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 7 | taoudenni
# Processing Record 33 of Set 7 | cherskiy
# Processing Record 34 of Set 7 | bamberg
# Processing Record 35 of Set 7 | la romana
# Processing Record 36 of Set 7 | yanam
# Processing Record 37 of Set 7 | maun
# Processing Record 38 of Set 7 | clyde river
# Processing Record 39 of Set 7 | damietta
# Processing Record 40 of Set 7 | bireun
# Processing Record 41 of Set 7 | bac lieu
# Processing Record 42 of Set 7 | yialos
# City not found. Skipping...
# Processing Record 43 of Set 7 | kudahuvadhoo
# Processing Record 44 of Set 7 | shumskiy
# Processing Record 45 of Set 7 | port said
# Processing Record 46 of Set 7 | najran
# Processing Record 47 of Set 7 | norman wells
# Processing Record 48 of Set 7 | chalons-en-champagne
# Processing Record 49 of Set 7 | qandahar
# City not found. Skipping...
# Processing Record 50 of Set 7 | evensk
# Processing Record 1 of Set 8 | bagdarin
# Processing Record 2 of Set 8 | bundi
# Processing Record 3 of Set 8 | san quintin
# Processing Record 4 of Set 8 | san cristobal
# Processing Record 5 of Set 8 | champerico
# Processing Record 6 of Set 8 | guantanamo
# Processing Record 7 of Set 8 | sistranda
# Processing Record 8 of Set 8 | camacha
# Processing Record 9 of Set 8 | vardo
# Processing Record 10 of Set 8 | mao
# Processing Record 11 of Set 8 | tahta
# Processing Record 12 of Set 8 | belaya gora
# Processing Record 13 of Set 8 | bandarbeyla
# Processing Record 14 of Set 8 | college
# Processing Record 15 of Set 8 | sao felix do xingu
# Processing Record 16 of Set 8 | khatanga
# Processing Record 17 of Set 8 | avera
# Processing Record 18 of Set 8 | ghanzi
# Processing Record 19 of Set 8 | lindsay
# Processing Record 20 of Set 8 | nador
# Processing Record 21 of Set 8 | chifeng
# Processing Record 22 of Set 8 | usinsk
# Processing Record 23 of Set 8 | timmins
# Processing Record 24 of Set 8 | makurdi
# Processing Record 25 of Set 8 | ugoofaaru
# Processing Record 26 of Set 8 | boguchar
# Processing Record 27 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 8 | limulunga
# Processing Record 29 of Set 8 | rome
# Processing Record 30 of Set 8 | moussoro
# Processing Record 31 of Set 8 | nola
# Processing Record 32 of Set 8 | tautira
# Processing Record 33 of Set 8 | bose
# Processing Record 34 of Set 8 | kpandae
# Processing Record 35 of Set 8 | jabiru
# City not found. Skipping...
# Processing Record 36 of Set 8 | ahuimanu
# Processing Record 37 of Set 8 | tabou
# Processing Record 38 of Set 8 | krasnoselkup
# Processing Record 39 of Set 8 | kibala
# Processing Record 40 of Set 8 | nioro
# Processing Record 41 of Set 8 | fort portal
# Processing Record 42 of Set 8 | gorontalo
# Processing Record 43 of Set 8 | pacific grove
# Processing Record 44 of Set 8 | shiyan
# Processing Record 45 of Set 8 | marystown
# Processing Record 46 of Set 8 | acapulco
# Processing Record 47 of Set 8 | peniche
# Processing Record 48 of Set 8 | dormidontovka
# Processing Record 49 of Set 8 | qostanay
# Processing Record 50 of Set 8 | boende
# Processing Record 1 of Set 9 | arcata
# Processing Record 2 of Set 9 | soyo
# Processing Record 3 of Set 9 | imbituba
# Processing Record 4 of Set 9 | neryungri
# Processing Record 5 of Set 9 | bukama
# Processing Record 6 of Set 9 | olafsvik
# Processing Record 7 of Set 9 | ipixuna
# Processing Record 8 of Set 9 | tessalit
# Processing Record 9 of Set 9 | roma
# Processing Record 10 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 11 of Set 9 | chamonix-mont-blanc
# Processing Record 12 of Set 9 | molokovo
# Processing Record 13 of Set 9 | palauig
# Processing Record 14 of Set 9 | ibiapina
# Processing Record 15 of Set 9 | andrelandia
# Processing Record 16 of Set 9 | anadyr
# Processing Record 17 of Set 9 | nyurba
# Processing Record 18 of Set 9 | cabedelo
# Processing Record 19 of Set 9 | eldikan
# City not found. Skipping...
# Processing Record 20 of Set 9 | orbetello
# Processing Record 21 of Set 9 | turukhansk
# Processing Record 22 of Set 9 | rorvik
# Processing Record 23 of Set 9 | vestmannaeyjar
# Processing Record 24 of Set 9 | yenotayevka
# Processing Record 25 of Set 9 | sfantu gheorghe
# Processing Record 26 of Set 9 | cururupu
# Processing Record 27 of Set 9 | nemuro
# Processing Record 28 of Set 9 | khaga
# Processing Record 29 of Set 9 | komsomolskiy
# Processing Record 30 of Set 9 | vallenar
# Processing Record 31 of Set 9 | joshimath
# Processing Record 32 of Set 9 | hargeysa
# Processing Record 33 of Set 9 | kikwit
# Processing Record 34 of Set 9 | bend
# Processing Record 35 of Set 9 | christchurch
# Processing Record 36 of Set 9 | okakarara
# Processing Record 37 of Set 9 | luderitz
# Processing Record 38 of Set 9 | bucerias
# Processing Record 39 of Set 9 | rawson
# Processing Record 40 of Set 9 | alzamay
# Processing Record 41 of Set 9 | susanville
# Processing Record 42 of Set 9 | lianyuan
# Processing Record 43 of Set 9 | bestobe
# Processing Record 44 of Set 9 | kizukuri
# Processing Record 45 of Set 9 | moranbah
# Processing Record 46 of Set 9 | margate
# Processing Record 47 of Set 9 | johi
# Processing Record 48 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 9 | ashqelon
# Processing Record 50 of Set 9 | atar
# Processing Record 1 of Set 10 | kindu
# Processing Record 2 of Set 10 | lidzbark warminski
# Processing Record 3 of Set 10 | assiniboia
# Processing Record 4 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 5 of Set 10 | linjiang
# Processing Record 6 of Set 10 | dolores
# Processing Record 7 of Set 10 | sol-iletsk
# Processing Record 8 of Set 10 | mount gambier
# Processing Record 9 of Set 10 | tay ninh
# Processing Record 10 of Set 10 | belmonte
# Processing Record 11 of Set 10 | salinas
# Processing Record 12 of Set 10 | bud
# Processing Record 13 of Set 10 | yar-sale
# Processing Record 14 of Set 10 | iranshahr
# Processing Record 15 of Set 10 | saint albans
# Processing Record 16 of Set 10 | santa rosa
# Processing Record 17 of Set 10 | sioux lookout
# Processing Record 18 of Set 10 | tura
# Processing Record 19 of Set 10 | hami
# Processing Record 20 of Set 10 | lincoln
# Processing Record 21 of Set 10 | la reforma
# Processing Record 22 of Set 10 | cap-aux-meules
# Processing Record 23 of Set 10 | valparaiso
# Processing Record 24 of Set 10 | one hundred mile house
# City not found. Skipping...
# Processing Record 25 of Set 10 | veraval
# Processing Record 26 of Set 10 | pryvillya
# Processing Record 27 of Set 10 | sendafa
# Processing Record 28 of Set 10 | rio gallegos
# Processing Record 29 of Set 10 | the valley
# Processing Record 30 of Set 10 | tigil
# Processing Record 31 of Set 10 | saint-francois
# Processing Record 32 of Set 10 | malumfashi
# Processing Record 33 of Set 10 | latung
# Processing Record 34 of Set 10 | odweyne
# Processing Record 35 of Set 10 | muros
# Processing Record 36 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 37 of Set 10 | tiznit
# Processing Record 38 of Set 10 | kavaratti
# Processing Record 39 of Set 10 | tabuk
# Processing Record 40 of Set 10 | erechim
# Processing Record 41 of Set 10 | satipo
# Processing Record 42 of Set 10 | salta
# Processing Record 43 of Set 10 | vung tau
# Processing Record 44 of Set 10 | mampong
# Processing Record 45 of Set 10 | nanakuli
# Processing Record 46 of Set 10 | oksfjord
# Processing Record 47 of Set 10 | geraldton
# Processing Record 48 of Set 10 | carroll
# Processing Record 49 of Set 10 | wismar
# Processing Record 50 of Set 10 | san patricio
# Processing Record 1 of Set 11 | bhikhi
# Processing Record 2 of Set 11 | lazaro cardenas
# Processing Record 3 of Set 11 | lujiang
# Processing Record 4 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 5 of Set 11 | parbhani
# Processing Record 6 of Set 11 | qasigiannguit
# Processing Record 7 of Set 11 | cam ranh
# Processing Record 8 of Set 11 | rybnaya sloboda
# Processing Record 9 of Set 11 | zlobin
# Processing Record 10 of Set 11 | maragogi
# Processing Record 11 of Set 11 | ixtapa
# Processing Record 12 of Set 11 | kourou
# Processing Record 13 of Set 11 | xinan
# Processing Record 14 of Set 11 | aswan
# Processing Record 15 of Set 11 | lasa
# Processing Record 16 of Set 11 | broken hill
# Processing Record 17 of Set 11 | beringovskiy
# Processing Record 18 of Set 11 | sofiyivka
# Processing Record 19 of Set 11 | sandy bay
# Processing Record 20 of Set 11 | honningsvag
# Processing Record 21 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 11 | lavrentiya
# Processing Record 23 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 24 of Set 11 | hokitika
# Processing Record 25 of Set 11 | darnah
# Processing Record 26 of Set 11 | kulevcha
# Processing Record 27 of Set 11 | mayo
# Processing Record 28 of Set 11 | pangnirtung
# Processing Record 29 of Set 11 | borogontsy
# Processing Record 30 of Set 11 | nova vicosa
# Processing Record 31 of Set 11 | diamantino
# Processing Record 32 of Set 11 | massakory
# Processing Record 33 of Set 11 | gubkinskiy
# Processing Record 34 of Set 11 | fez
# Processing Record 35 of Set 11 | salalah
# Processing Record 36 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 37 of Set 11 | udhampur
# Processing Record 38 of Set 11 | puerto carreno
# Processing Record 39 of Set 11 | hunchun
# Processing Record 40 of Set 11 | hobyo
# Processing Record 41 of Set 11 | ararat
# Processing Record 42 of Set 11 | pauini
# Processing Record 43 of Set 11 | catamarca
# Processing Record 44 of Set 11 | sur
# Processing Record 45 of Set 11 | fort nelson
# Processing Record 46 of Set 11 | el balyana
# City not found. Skipping...
# Processing Record 47 of Set 11 | rio grande
# Processing Record 48 of Set 11 | tofield
# Processing Record 49 of Set 11 | edson
# Processing Record 50 of Set 11 | haapsalu
# Processing Record 1 of Set 12 | aanekoski
# Processing Record 2 of Set 12 | bardiyah
# Processing Record 3 of Set 12 | concordia
# Processing Record 4 of Set 12 | zhangye
# Processing Record 5 of Set 12 | coari
# Processing Record 6 of Set 12 | hvide sande
# Processing Record 7 of Set 12 | marang
# Processing Record 8 of Set 12 | pangai
# Processing Record 9 of Set 12 | los llanos de aridane
# Processing Record 10 of Set 12 | shinjo
# Processing Record 11 of Set 12 | fallon
# Processing Record 12 of Set 12 | grindavik
# Processing Record 13 of Set 12 | okhotsk
# Processing Record 14 of Set 12 | qabis
# City not found. Skipping...
# Processing Record 15 of Set 12 | marsabit
# Processing Record 16 of Set 12 | sandwick
# Processing Record 17 of Set 12 | den helder
# Processing Record 18 of Set 12 | ust-kulom
# Processing Record 19 of Set 12 | tlahualilo
# City not found. Skipping...
# Processing Record 20 of Set 12 | paso de los toros
# Processing Record 21 of Set 12 | kieta
# Processing Record 22 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 23 of Set 12 | narsaq
# Processing Record 24 of Set 12 | evanston
# Processing Record 25 of Set 12 | elliot lake
# Processing Record 26 of Set 12 | gobabis
# Processing Record 27 of Set 12 | arlit
# Processing Record 28 of Set 12 | karratha
# Processing Record 29 of Set 12 | necochea
# Processing Record 30 of Set 12 | wexford
# Processing Record 31 of Set 12 | ende
# Processing Record 32 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 33 of Set 12 | boden
# Processing Record 34 of Set 12 | moose factory
# Processing Record 35 of Set 12 | tuy hoa
# Processing Record 36 of Set 12 | pasewalk
# Processing Record 37 of Set 12 | port-cartier
# Processing Record 38 of Set 12 | osypenko
# Processing Record 39 of Set 12 | brae
# Processing Record 40 of Set 12 | walvis bay
# Processing Record 41 of Set 12 | chabahar
# Processing Record 42 of Set 12 | zabol
# Processing Record 43 of Set 12 | sobolevo
# Processing Record 44 of Set 12 | bucksport
# Processing Record 45 of Set 12 | balangir
# Processing Record 46 of Set 12 | saint-augustin
# Processing Record 47 of Set 12 | ishige
# Processing Record 48 of Set 12 | boyolangu
# Processing Record 49 of Set 12 | nailsea
# Processing Record 50 of Set 12 | sumbe
# Processing Record 1 of Set 13 | grand gaube
# Processing Record 2 of Set 13 | pouembout
# Processing Record 3 of Set 13 | kupang
# Processing Record 4 of Set 13 | gerede
# Processing Record 5 of Set 13 | salekhard
# Processing Record 6 of Set 13 | warrington
# Processing Record 7 of Set 13 | kamenka
# Processing Record 8 of Set 13 | mount darwin
# Processing Record 9 of Set 13 | novaya zaimka
# Processing Record 10 of Set 13 | baruun-urt
# Processing Record 11 of Set 13 | cilegon
# Processing Record 12 of Set 13 | loukhi
# Processing Record 13 of Set 13 | liverpool
# Processing Record 14 of Set 13 | dunedin
# Processing Record 15 of Set 13 | smithers
# Processing Record 16 of Set 13 | pizarro
# Processing Record 17 of Set 13 | maracaibo
# Processing Record 18 of Set 13 | opobo
# City not found. Skipping...
# Processing Record 19 of Set 13 | port hardy
# Processing Record 20 of Set 13 | moron
# Processing Record 21 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 22 of Set 13 | kragujevac
# Processing Record 23 of Set 13 | san andres
# Processing Record 24 of Set 13 | toktogul
# Processing Record 25 of Set 13 | ellensburg
# Processing Record 26 of Set 13 | nouadhibou
# Processing Record 27 of Set 13 | novyy urengoy
# Processing Record 28 of Set 13 | banda aceh
# Processing Record 29 of Set 13 | north bend
# Processing Record 30 of Set 13 | poronaysk
# Processing Record 31 of Set 13 | bolgatanga
# Processing Record 32 of Set 13 | tsaratanana
# Processing Record 33 of Set 13 | udachnyy
# Processing Record 34 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 35 of Set 13 | sulur
# Processing Record 36 of Set 13 | uribia
# Processing Record 37 of Set 13 | cedar city
# Processing Record 38 of Set 13 | general roca
# Processing Record 39 of Set 13 | jacareacanga
# Processing Record 40 of Set 13 | corrales
# Processing Record 41 of Set 13 | florence
# Processing Record 42 of Set 13 | wagga wagga
# Processing Record 43 of Set 13 | mackay
# Processing Record 44 of Set 13 | berbera
# Processing Record 45 of Set 13 | kashi
# Processing Record 46 of Set 13 | portland
# Processing Record 47 of Set 13 | gerash
# Processing Record 48 of Set 13 | omboue
# Processing Record 49 of Set 13 | port macquarie
# Processing Record 50 of Set 13 | tondano
# Processing Record 1 of Set 14 | caxito
# Processing Record 2 of Set 14 | ketchikan
# Processing Record 3 of Set 14 | kishapu
# Processing Record 4 of Set 14 | harper
# Processing Record 5 of Set 14 | solnechnyy
# Processing Record 6 of Set 14 | altamont
# Processing Record 7 of Set 14 | zeya
# Processing Record 8 of Set 14 | mildura
# Processing Record 9 of Set 14 | skibbereen
# Processing Record 10 of Set 14 | atbasar
# Processing Record 11 of Set 14 | nueva concepcion
# Processing Record 12 of Set 14 | acajutla
# Processing Record 13 of Set 14 | maine-soroa
# Processing Record 14 of Set 14 | breves
# Processing Record 15 of Set 14 | shache
# Processing Record 16 of Set 14 | atasu
# Processing Record 17 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 14 | nuristan
# Processing Record 19 of Set 14 | kristiansund
# Processing Record 20 of Set 14 | kismayo
# Processing Record 21 of Set 14 | vaitape
# Processing Record 22 of Set 14 | taicheng
# Processing Record 23 of Set 14 | irmo
# Processing Record 24 of Set 14 | bilibino
# Processing Record 25 of Set 14 | arak
# Processing Record 26 of Set 14 | mongoumba
# Processing Record 27 of Set 14 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 28 of Set 14 | jumla
# Processing Record 29 of Set 14 | ningbo
# Processing Record 30 of Set 14 | shingu
# Processing Record 31 of Set 14 | aleksandrovskiy zavod
# Processing Record 32 of Set 14 | musoma
# Processing Record 33 of Set 14 | chenzhou
# Processing Record 34 of Set 14 | inhumas
# Processing Record 35 of Set 14 | berlevag
# Processing Record 36 of Set 14 | sarangani
# Processing Record 37 of Set 14 | pontiac
# Processing Record 38 of Set 14 | abu dhabi
# Processing Record 39 of Set 14 | alappuzha
# Processing Record 40 of Set 14 | san jose
# Processing Record 41 of Set 14 | upata
# Processing Record 42 of Set 14 | toftir
# City not found. Skipping...
# Processing Record 43 of Set 14 | muli
# Processing Record 44 of Set 14 | auki
# Processing Record 45 of Set 14 | songjianghe
# Processing Record 46 of Set 14 | seymchan
# Processing Record 47 of Set 14 | aksu
# Processing Record 48 of Set 14 | humberto de campos
# Processing Record 49 of Set 14 | russell
# Processing Record 50 of Set 14 | bohicon
# Processing Record 1 of Set 15 | bara
# Processing Record 2 of Set 15 | port-gentil
# Processing Record 3 of Set 15 | daru
# Processing Record 4 of Set 15 | xai-xai
# Processing Record 5 of Set 15 | richards bay
# Processing Record 6 of Set 15 | mezen
# Processing Record 7 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 8 of Set 15 | naze
# Processing Record 9 of Set 15 | samarai
# Processing Record 10 of Set 15 | bubaque
# Processing Record 11 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 12 of Set 15 | nioaque
# Processing Record 13 of Set 15 | yeppoon
# Processing Record 14 of Set 15 | caconda
# Processing Record 15 of Set 15 | bontang
# Processing Record 16 of Set 15 | gat
# Processing Record 17 of Set 15 | pakpattan
# Processing Record 18 of Set 15 | zhezkazgan
# Processing Record 19 of Set 15 | sakakah
# Processing Record 20 of Set 15 | bougouni
# Processing Record 21 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 22 of Set 15 | zhigansk
# Processing Record 23 of Set 15 | brownwood
# Processing Record 24 of Set 15 | shwebo
# Processing Record 25 of Set 15 | coihaique
# Processing Record 26 of Set 15 | baie-comeau
# Processing Record 27 of Set 15 | jacqueville
# Processing Record 28 of Set 15 | baijiantan
# Processing Record 29 of Set 15 | mangrol
# Processing Record 30 of Set 15 | taltal
# Processing Record 31 of Set 15 | hovd
# Processing Record 32 of Set 15 | henties bay
# Processing Record 33 of Set 15 | klaksvik
# Processing Record 34 of Set 15 | rundu
# Processing Record 35 of Set 15 | jiangyou
# Processing Record 36 of Set 15 | zaysan
# Processing Record 37 of Set 15 | praia
# Processing Record 38 of Set 15 | vostok
# Processing Record 39 of Set 15 | malanje
# Processing Record 40 of Set 15 | tshela
# Processing Record 41 of Set 15 | muzaffarabad
# Processing Record 42 of Set 15 | yuxia
# Processing Record 43 of Set 15 | gbarnga
# Processing Record 44 of Set 15 | rosetta
# Processing Record 45 of Set 15 | dickinson
# Processing Record 46 of Set 15 | belgrade
# Processing Record 47 of Set 15 | abu zabad
# Processing Record 48 of Set 15 | mecca
# Processing Record 49 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 50 of Set 15 | pasighat
# Processing Record 1 of Set 16 | manggar
# Processing Record 2 of Set 16 | gimli
# Processing Record 3 of Set 16 | aasiaat
# Processing Record 4 of Set 16 | prince rupert
# Processing Record 5 of Set 16 | cairns
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 689

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Albany  42.6001  -73.9662     43.66        69         100
# 1           Hilo  19.7297 -155.0900     71.26        75         100
# 2        Mataura -46.1927  168.8643     48.76        98          91
# 3  Santo Domingo  18.5001  -69.9886     84.04        76          40
# 4       Saldanha -33.0117   17.9442     71.65        62           0
# 5        Niteroi -22.8833  -43.1036     89.22        60          75
# 6          Guane  22.2025  -84.0875     79.23        70          82
# 7      Jamestown  42.0970  -79.2353     46.71        56          75
# 8         Hobart -42.8794  147.3294     57.06        77          40
# 9         Kodiak  57.7900 -152.4072     38.71        93         100
#
#    Wind Speed Country Current Description
# 0        3.76      US     overcast clouds
# 1        9.22      US     overcast clouds
# 2        2.37      NZ          light rain
# 3        5.99      DO    scattered clouds
# 4       30.94      ZA           clear sky
# 5       19.57      BR       moderate rain
# 6       13.49      CU       broken clouds
# 7       11.50      US       broken clouds
# 8        5.75      AU    scattered clouds
# 9       31.07      US          light rain

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order_list = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
reordered_city_df = city_data_df[new_column_order_list]

# Display sample data
reordered_city_df.head()
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Albany      US  42.6001  -73.9662     43.66        69         100
# 1           Hilo      US  19.7297 -155.0900     71.26        75         100
# 2        Mataura      NZ -46.1927  168.8643     48.76        98          91
# 3  Santo Domingo      DO  18.5001  -69.9886     84.04        76          40
# 4       Saldanha      ZA -33.0117   17.9442     71.65        62           0
#
#    Wind Speed Current Description
# 0        3.76     overcast clouds
# 1        9.22     overcast clouds
# 2        2.37          light rain
# 3        5.99    scattered clouds
# 4       30.94           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
reordered_city_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
with open('WeatherPy_Database.csv', 'w') as f:

    # Export the city_data DataFrame into a CSV file
    reordered_city_df.to_csv(f)
